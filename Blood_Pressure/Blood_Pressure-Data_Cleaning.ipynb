# %% [markdown]
# # DATA CLEANING ON `Patient_with_abnormal_bloodpressure.csv` DATASET

# %% [markdown]
# ###### - Importing pandas Library

# %%
import pandas as pd

# %% [markdown]
# ###### - Reading a csv File

# %%
bcc = pd.read_csv("Patient_with_abnormal_bloodpressure.csv")
bcc
# Out:
#       Patient_Number  Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                  1                           1                11.28
# 1                  2                           0                 9.75
# 2                  3                           1                10.79
# 3                  4                           0                11.00
# 4                  5                           1                14.17
# ...              ...                         ...                  ...
# 1995            1996                           1                10.14
# 1996            1997                           1                11.77
# 1997            1998                           1                16.91
# 1998            1999                           0                11.15
# 1999            2000                           1                11.36
#
#       Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# ...

# %% [markdown]
# ### Handeling Of Nulls

# %% [markdown]
# ###### - Checking for the columns contaning Null values

# %%
bcc.isnull().sum()
# Out:
# Patient_Number                      0
# Blood_Pressure_Abnormality          0
# Level_of_Hemoglobin                 0
# Genetic_Pedigree_Coefficient       92
# Age                                 0
# BMI                                 0
# Sex                                 0
# Pregnancy                        1558
# Smoking                             0
# Physical_activity                   0
# salt_content_in_the_diet            0
# alcohol_consumption_per_day       242
# Level_of_Stress                     0
# Chronic_kidney_disease              0
# Adrenal_and_thyroid_disorders       0
# dtype: int64

# %% [markdown]
# ###### - Filling the values in place of Nulls

# %%
bcc.alcohol_consumption_per_day.value_counts()
# Out:
# 253.0    11
# 401.0    10
# 302.0    10
# 144.0    10
# 485.0     9
#          ..
# 21.0      1
# 406.0     1
# 346.0     1
# 244.0     1
# 326.0     1
# Name: alcohol_consumption_per_day, Length: 488, dtype: int64

# %%
# bcc.Credit_Product.fillna("No", inplace = True)

bcc.Genetic_Pedigree_Coefficient.fillna(bcc.Genetic_Pedigree_Coefficient.mean() , inplace = True)
bcc.Pregnancy.fillna(0 , inplace = True)
bcc.alcohol_consumption_per_day.fillna(0 , inplace = True)

# %% [markdown]
# ###### - Checking for columns containing Null values after filling of values in place of Null

# %%
bcc.isnull().sum()[bcc.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# ### Droping Of Meaningless / Unwanted Columns

# %% [markdown]
# ###### - Droping the "Patient_Number" column from dataset

# %%
bcc.drop(columns = ["Patient_Number"], axis = 1, inplace = True)
bcc.head()
# Out:
#    Blood_Pressure_Abnormality  Level_of_Hemoglobin  \
# 0                           1                11.28
# 1                           0                 9.75
# 2                           1                10.79
# 3                           0                11.00
# 4                           1                14.17
#
#    Genetic_Pedigree_Coefficient  Age  BMI  Sex  Pregnancy  Smoking  \
# 0                          0.90   34   23    1        1.0        0
# 1                          0.23   54   33    1        0.0        0
# 2                          0.91   70   49    0        0.0        0
# 3                          0.43   71   50    0        0.0        0
# 4                          0.83   52   19    0        0.0        0
#
#    Physical_activity  salt_content_in_the_diet  alcohol_consumption_per_day  \
# 0              45961                     48071                          0.0
# 1              26106                     25333                        205.0
# ...
